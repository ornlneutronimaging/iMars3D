# %%
import numpy as np

# %%
from imars3d import sim

# %%
img = sim.randomBG(100, 80, 100, 5);
sim.addRandomOutliers(img, 5, 1000, 5)
# Out:
# array([[ 101.61176067,   97.29665718,   95.19101594, ...,  105.13355232,
#           97.33794633,  101.33348853],
#        [ 104.94925467,   95.95093945,   98.73222543, ...,  100.68159846,
#          105.13308854,   99.38262895],
#        [  97.83334044,   95.48205445,   98.10852173, ...,  101.08745929,
#           99.88538644,  107.73848027],
#        ...,
#        [ 104.72708122,  105.1550714 ,  104.1815768 , ...,  100.15032704,
#           98.50037125,   88.97565998],
#        [ 101.82327387,   95.40347363,  100.53130528, ...,   96.114368  ,
#          104.51428178,   98.01981404],
#        [ 101.61500817,   90.68245041,  102.12620421, ...,   98.91831172,
#           99.81624435,   96.53757636]])

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
#%matplotlib inline

# %%
fig = plt.figure()
plt.imshow(img, cmap='gray')
plt.colorbar()
# Out:
# <img src="data:image/png;base64,...">

# %%
import skimage

# %%
from skimage.restoration import denoise_bilateral

# %%
new_img = denoise_bilateral(img, sigma_range=0.1)
fig = plt.figure()
plt.imshow(new_img, cmap='gray')
plt.colorbar()
# Out:
# <img src="data:image/png;base64,...">

# %%
from imars3d import filters
new_img2 = filters.remove_outliers_bymedian(img.copy(), img>900)
fig = plt.figure()
plt.imshow(new_img2, cmap="gray")
plt.colorbar()
# Out:
# <img src="data:image/png;base64,...">

# %%
import numpy as np
print np.__version__
# Out:
# 1.10.1
