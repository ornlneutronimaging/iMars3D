# %%
# %gui qt

# %%
# %matplotlib inline

# %%
import numpy as np, os
os.chdir("/home/linjiao/dv/imaging/iMars3D/tests/workflows")

# %%
from imars3d import io; reload(io)
# Out:
# <module 'imars3d.io' from '/home/linjiao/dv/imaging/iMars3D/python/imars3d/io.pyc'>

# %%
datadir = "../iMars3D_large_dataset/reconstruction/turbine"
pattern = os.path.join("normalized_%7.3f.npy")
angles = np.arange(0, 182, .85)
normalized_ct = io.ImageSeries(pattern, angles, decimal_mark_replacement=".")

# %%
import matplotlib.pyplot as plt

# %%
ct_series = io.ImageSeries(
    os.path.join(datadir, "*CT*_%.3f_*.fits"),
    angles = np.arange(0, 182, .85),
    )

# %%
raw0 = ct_series.getData(0)
fig, ax = plt.subplots()
im = plt.imshow(raw0, cmap='gray')
plt.clim(0, 10000)
fig.colorbar(im)

# %%
df = np.load("df.npy")
fig, ax = plt.subplots()
im = plt.imshow(df, cmap='gray')
plt.clim(0, 1000)
fig.colorbar(im)

# %%
ob = np.load("ob.npy")
fig, ax = plt.subplots()
im = plt.imshow(ob, cmap='gray')
plt.clim(0, 10000)
fig.colorbar(im)

# %%
data0 = normalized_ct.getData(.85*50)
fig, ax = plt.subplots()
im = plt.imshow(data0, cmap='gray')
plt.clim(-.1, 1)
fig.colorbar(im)

# %%
tilted0 = io.ImageFile("tilted-0.npy").getData()
fig, ax = plt.subplots()
im = plt.imshow(tilted0, cmap='gray')
plt.clim(-.1, 1)
fig.colorbar(im)

# %%
tilted180 = io.ImageFile("tilted-180.npy").getData()
fig, ax = plt.subplots()
im = plt.imshow(tilted180, cmap='gray')
plt.clim(-.1, 1)
fig.colorbar(im)
